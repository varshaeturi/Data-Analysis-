# %%
import pandas as pd 


df = pd.read_csv("/home/varsha/created/codes/python_code/avocado.csv")

# %%
df.head(3)
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany

# %%
df.tail(2)
# Out:
#                  Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18247  10  2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248  11  2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df["AveragePrice"].head()
# Out:
# 0    1.33
# 1    1.35
# 2    0.93
# 3    1.08
# 4    1.28
# Name: AveragePrice, dtype: float64

# %%
df.AveragePrice.head()
# Out:
# 0    1.33
# 1    1.35
# 2    0.93
# 3    1.08
# 4    1.28
# Name: AveragePrice, dtype: float64

# %%
WestTexNewMexico_df = df[ df['region'] == "WestTexNewMexico"]
WestTexNewMexico_df.tail()
# Out:
#                  Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18244   7  2018-02-04          1.63      17074.83  2046.96  1529.20    0.00
# 18245   8  2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 18246   9  2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 18247  10  2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248  11  2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# ...

# %%
WestTexNewMexico_df.index
# Out:
# Int64Index([ 2756,  2757,  2758,  2759,  2760,  2761,  2762,  2763,  2764,
#              2765,
#             ...
#             18239, 18240, 18241, 18242, 18243, 18244, 18245, 18246, 18247,
#             18248],
#            dtype='int64', length=335)

# %%
WestTexNewMexico_df.set_index("Date")
# Out:
#                 AveragePrice  Total Volume       4046       4225      4770  \
# Date
# 2015-12-27   0          0.71     776404.39  451904.51  141599.36  15486.97
# 2015-12-20   1          0.83     649885.76  389110.55  108176.29  12953.59
# 2015-12-13   2          0.78     646041.56  437780.91  100110.13  13576.25
# 2015-12-06   3          0.74     623231.77  398871.12  133434.18  21088.12
# 2015-11-29   4          0.81     519028.45  335446.83  103635.94  11463.06
# ...         ..           ...           ...        ...        ...       ...
# 2018-02-04   7          1.63      17074.83    2046.96    1529.20      0.00
# 2018-01-28   8          1.71      13888.04    1191.70    3431.50      0.00
# 2018-01-21   9          1.87      13766.76    1191.92    2452.79    727.94
# 2018-01-14  10          1.93      16205.22    1527.63    2981.04    727.01
# 2018-01-07  11          1.62      17489.58    2894.77    2356.13    224.53
#
# ...

# %%
WestTexNewMexico_df.tail()
# Out:
#                  Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18244   7  2018-02-04          1.63      17074.83  2046.96  1529.20    0.00
# 18245   8  2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 18246   9  2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 18247  10  2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248  11  2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# ...

# %%
WestTexNewMexico_df = WestTexNewMexico_df.set_index("Date")

# %%
WestTexNewMexico_df.tail()
# Out:
#                 AveragePrice  Total Volume     4046     4225    4770  \
# Date
# 2018-02-04   7          1.63      17074.83  2046.96  1529.20    0.00
# 2018-01-28   8          1.71      13888.04  1191.70  3431.50    0.00
# 2018-01-21   9          1.87      13766.76  1191.92  2452.79  727.94
# 2018-01-14  10          1.93      16205.22  1527.63  2981.04  727.01
# 2018-01-07  11          1.62      17489.58  2894.77  2356.13  224.53
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2018-02-04    13498.67    13066.82      431.85          0.0  organic  2018
# 2018-01-28     9264.84     8940.04      324.80          0.0  organic  2018
# 2018-01-21     9394.11     9351.80       42.31          0.0  organic  2018
# 2018-01-14    10969.54    10919.54       50.00          0.0  organic  2018
# 2018-01-07    12014.15    11988.14       26.01          0.0  organic  2018
#
#                       region
# Date
# 2018-02-04  WestTexNewMexico
# ...

# %%
#WestTexNewMexico_df.set_index("Data", inplace=True)

# %%
WestTexNewMexico_df["AveragePrice"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df['AveragePrice'].rolling(25).mean().plot()

# %%
albany_df.sort_index(inplace=True)
albany_df['AveragePrice'].rolling(25).mean().plot()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 95

# %%
df['Date'] = pd.to_datetime(df["Date"])
albany_df = df[df["region"] == "Albany"]
albany_df.set_index("Date", inplace = True)
albany_df["AveragePrice"].plot()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 96
# <AxesSubplot:xlabel='Date'>

# %%
albany_df['AveragePrice'].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean().plot()
# Out:
# /tmp/ipykernel_46951/2287331562.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean().plot()

# %%
albany_df.head(3)
# Out:
#                AveragePrice  Total Volume     4046       4225    4770  \
# Date
# 2015-12-27  0          1.33      64236.62  1036.74   54454.85   48.16
# 2015-12-20  1          1.35      54876.98   674.28   44638.81   58.33
# 2015-12-13  2          0.93     118220.22   794.70  109149.67  130.50
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-12-27     8696.87     8603.62       93.25          0.0  conventional
# 2015-12-20     9505.56     9408.07       97.49          0.0  conventional
# 2015-12-13     8145.35     8042.21      103.14          0.0  conventional
#
#             year  region                          price25ma
# Date
# 2015-12-27  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-12-20  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-12-13  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)

# %%
albany_df.tail(3)
# Out:
#                 AveragePrice  Total Volume   4046    4225  4770  Total Bags  \
# Date
# 2018-01-21   9          1.54       3346.54  14.67  253.01   0.0     3078.86
# 2018-01-14  10          1.47       4140.95   7.30  301.87   0.0     3831.78
# 2018-01-07  11          1.54       4816.90  43.51  412.17   0.0     4361.22
#
#             Small Bags  Large Bags  XLarge Bags     type  year  region  \
# Date
# 2018-01-21     3078.86        0.00          0.0  organic  2018  Albany
# 2018-01-14     3831.78        0.00          0.0  organic  2018  Albany
# 2018-01-07     4357.89        3.33          0.0  organic  2018  Albany
#
#                                     price25ma
# Date
# 2018-01-21  AxesSubplot(0.125,0.2;0.775x0.68)
# 2018-01-14  AxesSubplot(0.125,0.2;0.775x0.68)
# 2018-01-07  AxesSubplot(0.125,0.2;0.775x0.68)

# %%
albany_df.dropna().head(3)
# Out:
#                AveragePrice  Total Volume     4046       4225    4770  \
# Date
# 2015-12-27  0          1.33      64236.62  1036.74   54454.85   48.16
# 2015-12-20  1          1.35      54876.98   674.28   44638.81   58.33
# 2015-12-13  2          0.93     118220.22   794.70  109149.67  130.50
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-12-27     8696.87     8603.62       93.25          0.0  conventional
# 2015-12-20     9505.56     9408.07       97.49          0.0  conventional
# 2015-12-13     8145.35     8042.21      103.14          0.0  conventional
#
#             year  region                          price25ma
# Date
# 2015-12-27  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-12-20  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-12-13  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
